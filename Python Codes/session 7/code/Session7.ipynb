# %% [markdown]
# # Mouse Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("mouse_viral_study.csv")

# %%
df.head()
# Out:
#    Med_1_mL  Med_2_mL  VIRUS
# 0  6.508231  8.582531       0
# 1  4.126116  3.073459       1
# 2  6.427870  6.369758       0
# 3  3.672953  4.905215       1
# 4  1.580321  2.440562       1

# %%
df.shape
# Out:
# (400, 3)

# %%
df.columns
# Out:
# Index(['Med_1_mL', 'Med_2_mL', 'VIRUS '], dtype='object')

# %%
sns.scatterplot(x='Med_1_mL',y='Med_2_mL',hue='VIRUS ',
                data=df,palette='seismic')
# Out:
# <Axes: xlabel='Med_1_mL', ylabel='Med_2_mL'>

# %%
sns.scatterplot(x='Med_1_mL',y='Med_2_mL',hue='VIRUS ',palette='seismic',data=df)

x = np.linspace(0,10,100)
m = -1
b = 11
y = m*x + b
plt.plot(x,y,'k')

# %%
from sklearn.svm import SVC

# %%
# ?SVC

# %%
df.head()
# Out:
#    Med_1_mL  Med_2_mL  VIRUS
# 0  6.508231  8.582531       0
# 1  4.126116  3.073459       1
# 2  6.427870  6.369758       0
# 3  3.672953  4.905215       1
# 4  1.580321  2.440562       1

# %%
df['VIRUS '].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    1
# Name: VIRUS , dtype: int64

# %%
y = df['VIRUS ']
X = df.drop('VIRUS ',axis=1)

# %%
model = SVC(kernel='linear', C=1000)
model.fit(X, y)
# Out:
# SVC(C=1000, kernel='linear')

# %%
from svm_margin_plot import plot_svm_boundary

# %%
plot_svm_boundary(model,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='linear', C=10000000)
model.fit(X, y)
plot_svm_boundary(model,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
plot_svm_boundary(model,X,y)

# %%
model = SVC(kernel='rbf', C=1)
model.fit(X, y)
plot_svm_boundary(model,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='sigmoid')
model.fit(X, y)
plot_svm_boundary(model,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='poly', C=1,degree=1)
model.fit(X, y)
plot_svm_boundary(model,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='poly', C=1,degree=5)
model.fit(X, y)
plot_svm_boundary(model,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='rbf', C=1,gamma=0.2)
model.fit(X, y)
plot_svm_boundary(model,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # **Homework Dataset**

# %%
new_df = pd.read_csv('dataset.txt')

# %%
new_df.head()
# Out:
#          x1       x2  y
# 0  0.051267  0.69956  1
# 1 -0.092742  0.68494  1
# 2 -0.213710  0.69225  1
# 3 -0.375000  0.50219  1
# 4 -0.513250  0.46564  1

# %%
sns.scatterplot(x='x1',y='x2',hue='y',
                data=new_df,palette='seismic')
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
y = new_df['y']
X = new_df.drop('y', axis=1)

# %%
model = SVC(kernel='linear', C=1)
model.fit(X, y)
plot_svm_boundary(model,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='rbf', C=100)
model.fit(X, y)
plot_svm_boundary(model,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
y_pred = model.predict(X)

# %%
accuracy = accuracy_score(y, y_pred)
print(f'Accuracy: {accuracy*100}')
# Out:
# Accuracy: 86.4406779661017

# %%
model = SVC(kernel='poly', degree=2, C=1000)
model.fit(X, y)
plot_svm_boundary(model,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
y_pred = model.predict(X)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y, y_pred)
print(f'Accuracy: {accuracy*100}')
# Out:
# Accuracy: 75.42372881355932

# %% [markdown]
# # **Homework Dataset with Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)

# %%
X_poly = poly.fit_transform(X)

# %%
X_poly[0]
# Out:
# array([1.        , 0.051267  , 0.69956   , 0.00262831, 0.03586434,
#        0.48938419])

# %%
model = LogisticRegression()

# %%
model.fit(X_poly, y)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_poly)

# %%
accuracy = accuracy_score(y, y_pred)
print(f'Accuracy: {accuracy*100}')
# Out:
# Accuracy: 81.35593220338984
