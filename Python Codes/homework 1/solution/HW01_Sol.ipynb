# %% [markdown]
# # **HW01 Solutions**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Question #1**

# %%
df = pd.read_csv('dataset.csv')

# %%
df.shape
# Out:
# (463, 12)

# %%
# Part 1
df.head(10)
# Out:
#    Unnamed: 0            Timestamp  Signal Strength (dBm)        SNR  \
# 0           0  2022-01-03 17:46:13             -84.119763  25.940082
# 1           1  2022-01-04 17:29:31             -87.806131  15.937354
# 2           2  2022-01-05 17:14:01            -116.575176  14.709384
# 3           3  2022-01-06 16:02:29             -82.961183  21.727165
# 4           4  2022-01-07 22:19:17             -85.012574  26.058158
# 5           5  2022-01-08 22:31:42             -98.618692  20.606738
# 6           6  2022-01-09 20:39:41             -74.139399  15.533144
# 7           7  2022-01-10 22:03:26             -50.235331  23.898983
# 8           8  2022-01-11 10:15:37             -70.103073  20.070370
# 9           9  2022-01-12 13:31:29             -97.600564  23.437814
#
#    Call Duration (s) Environment  Attenuation  Distance to Tower (km)  \
# 0        1713.800550       urban    14.690438                2.243176
# ...

# %%
# Part 2
df = df.drop('Unnamed: 0', axis=1)
df.head()
# Out:
#              Timestamp  Signal Strength (dBm)        SNR  Call Duration (s)  \
# 0  2022-01-03 17:46:13             -84.119763  25.940082        1713.800550
# 1  2022-01-04 17:29:31             -87.806131  15.937354         345.371848
# 2  2022-01-05 17:14:01            -116.575176  14.709384         259.285043
# 3  2022-01-06 16:02:29             -82.961183  21.727165         357.974004
# 4  2022-01-07 22:19:17             -85.012574  26.058158         398.006716
#
#   Environment  Attenuation  Distance to Tower (km)  Tower ID  User ID  \
# 0       urban    14.690438                2.243176       5.0     25.0
# 1        home     6.213698                5.002566       3.0     22.0
# 2        open     4.494415                8.705974       2.0      5.0
# 3        home     7.619957                7.427025       5.0     33.0
# 4       urban    10.655159                0.612071       5.0      8.0
#
#   Call Type Incoming/Outgoing
# 0      data          incoming
# ...

# %%
# Part 3
df.isnull().sum()
# Out:
# Timestamp                  4
# Signal Strength (dBm)      5
# SNR                       11
# Call Duration (s)          5
# Environment               13
# Attenuation                8
# Distance to Tower (km)    12
# Tower ID                  18
# User ID                   12
# Call Type                  8
# Incoming/Outgoing          4
# dtype: int64

# %%
# Part 3
df['Call Duration (s)'] = df['Call Duration (s)'].fillna(df['Call Duration (s)'].mean())

# %%
# Part 3
df = df.dropna()
df.head()
# Out:
#              Timestamp  Signal Strength (dBm)        SNR  Call Duration (s)  \
# 0  2022-01-03 17:46:13             -84.119763  25.940082        1713.800550
# 1  2022-01-04 17:29:31             -87.806131  15.937354         345.371848
# 2  2022-01-05 17:14:01            -116.575176  14.709384         259.285043
# 3  2022-01-06 16:02:29             -82.961183  21.727165         357.974004
# 4  2022-01-07 22:19:17             -85.012574  26.058158         398.006716
#
#   Environment  Attenuation  Distance to Tower (km)  Tower ID  User ID  \
# 0       urban    14.690438                2.243176       5.0     25.0
# 1        home     6.213698                5.002566       3.0     22.0
# 2        open     4.494415                8.705974       2.0      5.0
# 3        home     7.619957                7.427025       5.0     33.0
# 4       urban    10.655159                0.612071       5.0      8.0
#
#   Call Type Incoming/Outgoing
# 0      data          incoming
# ...

# %%
df.shape
# Out:
# (379, 11)

# %% [markdown]
# ## **Question #2**

# %%
df.describe().T
# Out:
#                         count        mean         std         min         25%  \
# Signal Strength (dBm)   379.0  -84.961710   14.516850 -118.681318  -96.989475
# SNR                     379.0   19.848989    5.554188   10.271411   15.084747
# Call Duration (s)       379.0  922.601787  525.250202   11.520904  454.810271
# Attenuation             379.0    5.448509    3.504256    0.042255    2.785211
# Distance to Tower (km)  379.0    5.095061    2.965653    0.026375    2.477556
# Tower ID                379.0    5.567282    2.851266    1.000000    3.000000
# User ID                 379.0   51.717678   28.218103    1.000000   28.000000
#
#                                50%          75%          max
# Signal Strength (dBm)   -84.217633   -74.421831   -50.122222
# SNR                      19.587542    24.637686    29.963213
# Call Duration (s)       928.627968  1397.740799  1795.175137
# Attenuation               4.744233     7.598476    14.939793
# ...

# %%
sns.histplot(df['Signal Strength (dBm)'])
# Out:
# <Axes: xlabel='Signal Strength (dBm)', ylabel='Count'>

# %% [markdown]
# ## **Question #3**

# %%
condition = (df['Environment'] == 'urban') & (df['Distance to Tower (km)'] < 5)
df[condition].head()
# Out:
#               Timestamp  Signal Strength (dBm)        SNR  Call Duration (s)  \
# 0   2022-01-03 17:46:13             -84.119763  25.940082        1713.800550
# 4   2022-01-07 22:19:17             -85.012574  26.058158         398.006716
# 5   2022-01-08 22:31:42             -98.618692  20.606738        1795.175137
# 34  2022-02-06 13:17:38            -101.526350  16.196757          82.799869
# 46  2022-02-18 14:00:53             -78.150989  19.621375         308.517922
#
#    Environment  Attenuation  Distance to Tower (km)  Tower ID  User ID  \
# 0        urban    14.690438                2.243176       5.0     25.0
# 4        urban    10.655159                0.612071       5.0      8.0
# 5        urban     5.622202                4.702561       6.0     42.0
# 34       urban    10.081126                1.179915      10.0     43.0
# 46       urban    11.061298                1.526207       9.0      5.0
#
#    Call Type Incoming/Outgoing
# 0       data          incoming
# ...

# %% [markdown]
# ## **Question #4**

# %%
df['Call Duration (m)'] = round(df['Call Duration (s)'] / 60, 2)
df.head()
# Out:
#              Timestamp  Signal Strength (dBm)        SNR  Call Duration (s)  \
# 0  2022-01-03 17:46:13             -84.119763  25.940082        1713.800550
# 1  2022-01-04 17:29:31             -87.806131  15.937354         345.371848
# 2  2022-01-05 17:14:01            -116.575176  14.709384         259.285043
# 3  2022-01-06 16:02:29             -82.961183  21.727165         357.974004
# 4  2022-01-07 22:19:17             -85.012574  26.058158         398.006716
#
#   Environment  Attenuation  Distance to Tower (km)  Tower ID  User ID  \
# 0       urban    14.690438                2.243176       5.0     25.0
# 1        home     6.213698                5.002566       3.0     22.0
# 2        open     4.494415                8.705974       2.0      5.0
# 3        home     7.619957                7.427025       5.0     33.0
# 4       urban    10.655159                0.612071       5.0      8.0
#
#   Call Type Incoming/Outgoing  Call Duration (m)
# ...

# %% [markdown]
# ## **Question #5**

# %%
df.groupby('Environment').mean()[['Call Duration (s)']]
# Out:
# <ipython-input-25-43d0877a0394>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Environment').mean()[['Call Duration (s)']]
#              Call Duration (s)
# Environment
# home                928.909300
# open                901.108388
# suburban            914.851166
# urban               948.491363

# %% [markdown]
# ## **Question #6**

# %%
sns.scatterplot(data = df, x='Signal Strength (dBm)', y='Distance to Tower (km)')
# Out:
# <Axes: xlabel='Signal Strength (dBm)', ylabel='Distance to Tower (km)'>
